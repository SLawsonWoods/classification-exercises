# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pydataset import data

# %%
df = pd.read_csv('attendance.csv')

# %%
df.head()
# Out:
#   Unnamed: 0 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05  \
# 0      Sally          P          T          T          H          P
# 1       Jane          A          P          T          T          T
# 2      Billy          A          T          A          A          H
# 3       John          P          T          H          P          P
#
#   2018-01-06 2018-01-07 2018-01-08
# 0          A          T          T
# 1          T          A          T
# 2          T          P          T
# 3          T          P          P

# %% [markdown]
# Load the attendance.csv file and calculate an attendnace percentage for each student. One half day is worth 50% of a full day, and 10 tardies is equal to one absence.

# %%
df.info
# Out:
# <bound method DataFrame.info of   Unnamed: 0 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05  \
# 0      Sally          P          T          T          H          P
# 1       Jane          A          P          T          T          T
# 2      Billy          A          T          A          A          H
# 3       John          P          T          H          P          P
#
#   2018-01-06 2018-01-07 2018-01-08
# 0          A          T          T
# 1          T          A          T
# 2          T          P          T
# 3          T          P          P  >

# %%
#melt df
df_long =df.melt(id_vars='Unnamed: 0', var_name = 'date',
                 value_name='status')

# %%
#rename columns
df_long.columns =['name','date','status']

# %%
df_long
# Out:
#      name        date status
# 0   Sally  2018-01-01      P
# 1    Jane  2018-01-01      A
# 2   Billy  2018-01-01      A
# 3    John  2018-01-01      P
# 4   Sally  2018-01-02      T
# 5    Jane  2018-01-02      P
# 6   Billy  2018-01-02      T
# 7    John  2018-01-02      T
# 8   Sally  2018-01-03      T
# 9    Jane  2018-01-03      T
# 10  Billy  2018-01-03      A
# 11   John  2018-01-03      H
# 12  Sally  2018-01-04      H
# 13   Jane  2018-01-04      T
# 14  Billy  2018-01-04      A
# 15   John  2018-01-04      P
# 16  Sally  2018-01-05      P
# 17   Jane  2018-01-05      T
# 18  Billy  2018-01-05      H
# 19   John  2018-01-05      P
# 20  Sally  2018-01-06      A
# 21   Jane  2018-01-06      T
# 22  Billy  2018-01-06      T
# 23   John  2018-01-06      T
# 24  Sally  2018-01-07      T
# 25   Jane  2018-01-07      A
# 26  Billy  2018-01-07      P
# 27   John  2018-01-07      P
# 28  Sally  2018-01-08      T
# 29   Jane  2018-01-08      T
# 30  Billy  2018-01-08      T
# ...

# %%
#indicate values for variables

df_long.status = ((df_long.status == 'P')| (df_long.status == 'T') 
                     | (df_long.status =='A').map({'P':.5,'T':.9,'A':1}))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-2c3275e77a66> in <module>
#       1 #replace variables for attendance with values
#       2
# ----> 3 df_long.status = ((df_long.status == 'P')| (df_long.status == 'T')
#       4                      | (df_long.status =='A').map({'P':.5,'T':.9,'A':1}))
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'status'

# %%
df_long['calculation']= df_long['status'].where('P'==.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-1cbd43a96386> in <module>
#       1 #air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882
# ----> 2 df_long['calculation']= df_long['status'].where('P'==.5)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ...
